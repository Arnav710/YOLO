# %%
from ultralytics import YOLO
import cv2
import cvzone
import math
import time

cap = cv2.VideoCapture(0)  # For Webcam
cap.set(3, 1280)
cap.set(4, 720)

model = YOLO("../Yolo-Weights/yolov8l.pt")

classNames = ["person", "bicycle", "car", "motorbike", "aeroplane", "bus", "train", "truck", "boat",
              "traffic light", "fire hydrant", "stop sign", "parking meter", "bench", "bird", "cat",
              "dog", "horse", "sheep", "cow", "elephant", "bear", "zebra", "giraffe", "backpack", "umbrella",
              "handbag", "tie", "suitcase", "frisbee", "skis", "snowboard", "sports ball", "kite", "baseball bat",
              "baseball glove", "skateboard", "surfboard", "tennis racket", "bottle", "wine glass", "cup",
              "fork", "knife", "spoon", "bowl", "banana", "apple", "sandwich", "orange", "broccoli",
              "carrot", "hot dog", "pizza", "donut", "cake", "chair", "sofa", "pottedplant", "bed",
              "diningtable", "toilet", "tvmonitor", "laptop", "mouse", "remote", "keyboard", "cell phone",
              "microwave", "oven", "toaster", "sink", "refrigerator", "book", "clock", "vase", "scissors",
              "teddy bear", "hair drier", "toothbrush"
              ]

prev_frame_time = 0
new_frame_time = 0

while True:
    new_frame_time = time.time()
    
    # Capture frame-by-frame
    ret, frame = cap.read()
    
    # Check if frame is valid
    if not ret:
        print("Error: Failed to capture frame")
        break
    
    # Perform object detection
    results = model(frame, stream=True)
    
    for r in results:
        boxes = r.boxes
        for box in boxes:
            # Bounding Box
            x1, y1, x2, y2 = box.xyxy[0]
            x1, y1, x2, y2 = int(x1), int(y1), int(x2), int(y2)
            w, h = x2 - x1, y2 - y1
            cvzone.cornerRect(frame, (x1, y1, w, h))
            # Confidence
            conf = math.ceil((box.conf[0] * 100)) / 100
            # Class Name
            cls = int(box.cls[0])
 
            cvzone.putTextRect(frame, f'{classNames[cls]} {conf}', (max(0, x1), max(35, y1)), scale=1, thickness=1)
    
    fps = 1 / (new_frame_time - prev_frame_time)
    prev_frame_time = new_frame_time
    print(fps)
    
    # Display the resulting frame
    cv2.imshow('Frame', frame)
    if cv2.waitKey(1) & 0xFF == ord('q'):
        break

# Release the capture
cap.release()
cv2.destroyAllWindows()
# Out:
# 0: 384x640 1 person, 1321.2ms
# Speed: 9.6ms preprocess, 1321.2ms inference, 15.4ms postprocess per image at shape (1, 3, 384, 640)
# 5.842031814512847e-10
#
# 0: 384x640 1 person, 1056.6ms
# Speed: 3.2ms preprocess, 1056.6ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
# 0.3593410023173844
#
# 0: 384x640 1 person, 810.7ms
# Speed: 2.6ms preprocess, 810.7ms inference, 2.4ms postprocess per image at shape (1, 3, 384, 640)
# 0.8851810870307999
#
# 0: 384x640 1 person, 786.7ms
# Speed: 2.5ms preprocess, 786.7ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
# 1.1399132598123547
#
# 0: 384x640 1 person, 803.8ms
# Speed: 2.3ms preprocess, 803.8ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# 1.1920499385544785
#
# 0: 384x640 1 person, 1129.9ms
# Speed: 3.3ms preprocess, 1129.9ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
# 1.1768291998590377
#
# 0: 384x640 1 person, 876.0ms
# Speed: 4.1ms preprocess, 876.0ms inference, 2.6ms postprocess per image at shape (1, 3, 384, 640)
# 0.8365897933469802
#
# 0: 384x640 1 person, 1276.0ms
# Speed: 2.7ms preprocess, 1276.0ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
# 1.0569238487886954
#
# 0: 384x640 1 person, 902.9ms
# Speed: 3.9ms preprocess, 902.9ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# 0.7522523338488477
#
# 0: 384x640 1 person, 999.2ms
# Speed: 3.0ms preprocess, 999.2ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
# 1.0370712500871582
#
# 0: 384x640 1 person, 941.3ms
# Speed: 4.2ms preprocess, 941.3ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
# 0.9412801784218294
#
# 0: 384x640 1 person, 845.1ms
# Speed: 3.1ms preprocess, 845.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# 0.989898994666875
#
# 0: 384x640 1 person, 964.1ms
# Speed: 2.4ms preprocess, 964.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# 1.1095613767298935
#
# 0: 384x640 1 person, 898.7ms
# Speed: 2.2ms preprocess, 898.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# 0.988958375037991
#
# 0: 384x640 1 person, 833.3ms
# Speed: 2.4ms preprocess, 833.3ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
# 1.0581125034656096
#
# 0: 384x640 1 person, 839.0ms
# Speed: 2.7ms preprocess, 839.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# 1.1121218058976365
#
# 0: 384x640 1 person, 979.2ms
# Speed: 2.4ms preprocess, 979.2ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
# 1.0817302199436065
#
# 0: 384x640 1 person, 805.2ms
# Speed: 3.2ms preprocess, 805.2ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
# 0.9829816354653942
#
# 0: 384x640 1 person, 854.6ms
# Speed: 3.1ms preprocess, 854.6ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
# 1.1684082413331927
#
# 0: 384x640 2 persons, 903.5ms
# Speed: 3.1ms preprocess, 903.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# 1.0939115221690114
#
# 0: 384x640 2 persons, 868.2ms
# Speed: 2.4ms preprocess, 868.2ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
# 1.0528730380866913
#
# 0: 384x640 2 persons, 865.1ms
# Speed: 2.7ms preprocess, 865.1ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
# 1.0747906821325541
#
# 0: 384x640 2 persons, 875.9ms
# Speed: 3.0ms preprocess, 875.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# 1.0764120147001457
#
# 0: 384x640 2 persons, 843.5ms
# Speed: 2.4ms preprocess, 843.5ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
# 1.0985101521014622
#
# 0: 384x640 3 persons, 852.0ms
# Speed: 2.7ms preprocess, 852.0ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
# 1.108796102311675
#
# 0: 384x640 1 person, 864.3ms
# Speed: 3.3ms preprocess, 864.3ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# 1.096368627100404
#
# 0: 384x640 1 person, 1 refrigerator, 974.1ms
# Speed: 3.2ms preprocess, 974.1ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
# 1.1028094097478762
#
# 0: 384x640 1 person, 1 refrigerator, 953.3ms
# Speed: 2.6ms preprocess, 953.3ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
# 0.9881375546098435
#
# 0: 384x640 1 person, 842.8ms
# Speed: 2.8ms preprocess, 842.8ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# 0.9895297691453291
#
# 0: 384x640 1 person, 1 refrigerator, 838.7ms
# Speed: 2.8ms preprocess, 838.7ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
# 1.1275304759290767
#
# 0: 384x640 1 person, 1 refrigerator, 892.0ms
# Speed: 2.4ms preprocess, 892.0ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
# 1.1109479508018694
#
# 0: 384x640 1 person, 1 refrigerator, 867.3ms
# Speed: 2.5ms preprocess, 867.3ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
# 1.0501257230357701
#
# 0: 384x640 1 person, 1 refrigerator, 871.9ms
# Speed: 3.2ms preprocess, 871.9ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
# 1.1010186177836532
#
# 0: 384x640 1 person, 834.7ms
# Speed: 2.4ms preprocess, 834.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# 1.0631081569514478
#
# 0: 384x640 1 person, 1 refrigerator, 894.2ms
# Speed: 2.9ms preprocess, 894.2ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# 1.1223206002615347
#
# 0: 384x640 1 person, 1 refrigerator, 860.2ms
# Speed: 2.7ms preprocess, 860.2ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
# 1.0403953711962837
#
# 0: 384x640 1 person, 1 refrigerator, 892.6ms
# Speed: 2.5ms preprocess, 892.6ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
# 1.1132966667489501
#
# 0: 384x640 1 person, 1 refrigerator, 911.8ms
# Speed: 2.5ms preprocess, 911.8ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
# 1.072441578670954
#
# 0: 384x640 1 person, 1 refrigerator, 831.3ms
# Speed: 2.6ms preprocess, 831.3ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
# 1.0481837172438215
#
# 0: 384x640 1 person, 1 refrigerator, 856.7ms
# Speed: 2.6ms preprocess, 856.7ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
# 1.1275777626811716
#
# 0: 384x640 1 person, 1 refrigerator, 819.7ms
# Speed: 2.8ms preprocess, 819.7ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
# 1.0857856011034137
#
# 0: 384x640 1 person, 1 refrigerator, 905.0ms
# Speed: 2.4ms preprocess, 905.0ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
# 1.1132136365952676
#
# 0: 384x640 1 person, 891.6ms
# Speed: 2.4ms preprocess, 891.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# 1.0547112553725018
#
# 0: 384x640 1 person, 900.6ms
# Speed: 2.7ms preprocess, 900.6ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
# 1.0509545729372
#
# 0: 384x640 1 person, 1 refrigerator, 919.5ms
# Speed: 3.0ms preprocess, 919.5ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
# 1.0609987033177963
#
# 0: 384x640 1 person, 881.7ms
# Speed: 3.5ms preprocess, 881.7ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
# 1.0402624823070228
#
# 0: 384x640 1 person, 1 refrigerator, 917.3ms
# Speed: 2.5ms preprocess, 917.3ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
# 1.0823577379485465
#
# 0: 384x640 1 person, 872.2ms
# Speed: 2.4ms preprocess, 872.2ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
# 1.0318235704658096
#
# 0: 384x640 1 person, 1 refrigerator, 1011.0ms
# Speed: 29.5ms preprocess, 1011.0ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
# 1.0872362172209986
#
# 0: 384x640 1 person, 1 refrigerator, 920.8ms
# Speed: 2.4ms preprocess, 920.8ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
# 0.9057373677258246
#
# 0: 384x640 2 persons, 924.4ms
# Speed: 2.5ms preprocess, 924.4ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# 1.0224478562572734
#
# 0: 384x640 1 person, 1 dining table, 921.2ms
# Speed: 2.4ms preprocess, 921.2ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
# 1.0335726592779217
#
# 0: 384x640 1 person, 952.1ms
# Speed: 2.5ms preprocess, 952.1ms inference, 7.4ms postprocess per image at shape (1, 3, 384, 640)
# 1.0384441599424812
#
# 0: 384x640 1 person, 892.6ms
# Speed: 3.4ms preprocess, 892.6ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
# 0.9978009053304494
#
# 0: 384x640 1 person, 1 chair, 1146.5ms
# Speed: 2.3ms preprocess, 1146.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# 1.0694167944910413
#
# 0: 384x640 1 person, 1 chair, 894.2ms
# Speed: 2.4ms preprocess, 894.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# 0.8489122607319708
#
# 0: 384x640 1 person, 1 bench, 814.2ms
# Speed: 2.3ms preprocess, 814.2ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
# 0.763203797036713
#
# 0: 384x640 1 person, 1 bench, 1 chair, 913.3ms
# Speed: 2.7ms preprocess, 913.3ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# 1.1503058895287241
#
# 0: 384x640 1 person, 1 chair, 918.3ms
# Speed: 3.1ms preprocess, 918.3ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
# 1.034594745261226
#
# 0: 384x640 1 person, 1 bench, 879.8ms
# Speed: 1.8ms preprocess, 879.8ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
# 0.7840831808214518
#
# 0: 384x640 1 person, 1 chair, 935.2ms
# Speed: 3.3ms preprocess, 935.2ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
# 1.0872615825534382
#
# 0: 384x640 1 person, 1 bench, 1 chair, 900.1ms
# Speed: 2.6ms preprocess, 900.1ms inference, 16.3ms postprocess per image at shape (1, 3, 384, 640)
# 1.013378330448531
#
# 0: 384x640 1 person, 1 bench, 1 chair, 944.4ms
# Speed: 4.6ms preprocess, 944.4ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
# 1.0197849221844282
#
# 0: 384x640 1 person, 1 chair, 900.4ms
# Speed: 4.0ms preprocess, 900.4ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
# 1.0018253205059304
#
# 0: 384x640 1 person, 1 chair, 833.0ms
# Speed: 2.2ms preprocess, 833.0ms inference, 7.9ms postprocess per image at shape (1, 3, 384, 640)
# 1.044658270321726
#
# 0: 384x640 1 person, 1 chair, 879.3ms
# Speed: 3.4ms preprocess, 879.3ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
# 1.1141933535240784
#
# 0: 384x640 1 person, 1 chair, 898.8ms
# Speed: 3.3ms preprocess, 898.8ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
# 1.0604994605599405
#
# 0: 384x640 1 person, 1 chair, 786.4ms
# Speed: 2.5ms preprocess, 786.4ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
# 1.0492574927415357
#
# 0: 384x640 1 person, 1 chair, 863.2ms
# Speed: 3.0ms preprocess, 863.2ms inference, 5.6ms postprocess per image at shape (1, 3, 384, 640)
# 1.1742366405268172
#
# 0: 384x640 1 person, 1 chair, 1229.5ms
# Speed: 3.3ms preprocess, 1229.5ms inference, 13.5ms postprocess per image at shape (1, 3, 384, 640)
# 1.079957958332196
#
# 0: 384x640 1 person, 1 chair, 1001.8ms
# Speed: 3.2ms preprocess, 1001.8ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
# 0.7668694012215267
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[2], line 42
#      39 # Perform object detection
#      40 results = model(frame, stream=True)
# ---> 42 for r in results:
#      43     boxes = r.boxes
#      44     for box in boxes:
#      45         # Bounding Box
#
# File /opt/homebrew/lib/python3.11/site-packages/torch/utils/_contextlib.py:35, in _wrap_generator.<locals>.generator_context(*args, **kwargs)
#      32 try:
#      33     # Issuing `None` to a generator fires it up
#      34     with ctx_factory():
# ---> 35         response = gen.send(None)
#      37     while True:
#      38         try:
#      39             # Forward the response to our caller and get its next request
#
# File /opt/homebrew/lib/python3.11/site-packages/ultralytics/engine/predictor.py:248, in BasePredictor.stream_inference(self, source, model, *args, **kwargs)
#     246 # Inference
#     247 with profilers[1]:
# --> 248     preds = self.inference(im, *args, **kwargs)
#     249     if self.args.embed:
#     250         yield from [preds] if isinstance(preds, torch.Tensor) else preds  # yield embedding tensors
#
# File /opt/homebrew/lib/python3.11/site-packages/ultralytics/engine/predictor.py:142, in BasePredictor.inference(self, im, *args, **kwargs)
#     136 """Runs inference on a given image using the specified model and arguments."""
#     137 visualize = (
#     138     increment_path(self.save_dir / Path(self.batch[0][0]).stem, mkdir=True)
#     139     if self.args.visualize and (not self.source_type.tensor)
#     140     else False
#     141 )
# --> 142 return self.model(im, augment=self.args.augment, visualize=visualize, embed=self.args.embed, *args, **kwargs)
#
# File /opt/homebrew/lib/python3.11/site-packages/torch/nn/modules/module.py:1511, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1509     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1510 else:
# -> 1511     return self._call_impl(*args, **kwargs)
#
# File /opt/homebrew/lib/python3.11/site-packages/torch/nn/modules/module.py:1520, in Module._call_impl(self, *args, **kwargs)
#    1515 # If we don't have any hooks, we want to skip the rest of the logic in
#    1516 # this function, and just call forward.
#    1517 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1518         or _global_backward_pre_hooks or _global_backward_hooks
#    1519         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1520     return forward_call(*args, **kwargs)
#    1522 try:
#    1523     result = None
#
# File /opt/homebrew/lib/python3.11/site-packages/ultralytics/nn/autobackend.py:423, in AutoBackend.forward(self, im, augment, visualize, embed)
#     421 # PyTorch
#     422 if self.pt or self.nn_module:
# --> 423     y = self.model(im, augment=augment, visualize=visualize, embed=embed)
#     425 # TorchScript
#     426 elif self.jit:
#
# File /opt/homebrew/lib/python3.11/site-packages/torch/nn/modules/module.py:1511, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1509     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1510 else:
# -> 1511     return self._call_impl(*args, **kwargs)
#
# File /opt/homebrew/lib/python3.11/site-packages/torch/nn/modules/module.py:1520, in Module._call_impl(self, *args, **kwargs)
#    1515 # If we don't have any hooks, we want to skip the rest of the logic in
#    1516 # this function, and just call forward.
#    1517 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1518         or _global_backward_pre_hooks or _global_backward_hooks
#    1519         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1520     return forward_call(*args, **kwargs)
#    1522 try:
#    1523     result = None
#
# File /opt/homebrew/lib/python3.11/site-packages/ultralytics/nn/tasks.py:89, in BaseModel.forward(self, x, *args, **kwargs)
#      87 if isinstance(x, dict):  # for cases of training and validating while training.
#      88     return self.loss(x, *args, **kwargs)
# ---> 89 return self.predict(x, *args, **kwargs)
#
# File /opt/homebrew/lib/python3.11/site-packages/ultralytics/nn/tasks.py:107, in BaseModel.predict(self, x, profile, visualize, augment, embed)
#     105 if augment:
#     106     return self._predict_augment(x)
# --> 107 return self._predict_once(x, profile, visualize, embed)
#
# File /opt/homebrew/lib/python3.11/site-packages/ultralytics/nn/tasks.py:128, in BaseModel._predict_once(self, x, profile, visualize, embed)
#     126 if profile:
#     127     self._profile_one_layer(m, x, dt)
# --> 128 x = m(x)  # run
#     129 y.append(x if m.i in self.save else None)  # save output
#     130 if visualize:
#
# File /opt/homebrew/lib/python3.11/site-packages/torch/nn/modules/module.py:1511, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1509     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1510 else:
# -> 1511     return self._call_impl(*args, **kwargs)
#
# File /opt/homebrew/lib/python3.11/site-packages/torch/nn/modules/module.py:1520, in Module._call_impl(self, *args, **kwargs)
#    1515 # If we don't have any hooks, we want to skip the rest of the logic in
#    1516 # this function, and just call forward.
#    1517 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1518         or _global_backward_pre_hooks or _global_backward_hooks
#    1519         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1520     return forward_call(*args, **kwargs)
#    1522 try:
#    1523     result = None
#
# File /opt/homebrew/lib/python3.11/site-packages/ultralytics/nn/modules/block.py:175, in SPPF.forward(self, x)
#     173 """Forward pass through Ghost Convolution block."""
#     174 y = [self.cv1(x)]
# --> 175 y.extend(self.m(y[-1]) for _ in range(3))
#     176 return self.cv2(torch.cat(y, 1))
#
# File /opt/homebrew/lib/python3.11/site-packages/ultralytics/nn/modules/block.py:175, in <genexpr>(.0)
#     173 """Forward pass through Ghost Convolution block."""
#     174 y = [self.cv1(x)]
# --> 175 y.extend(self.m(y[-1]) for _ in range(3))
#     176 return self.cv2(torch.cat(y, 1))
#
# File /opt/homebrew/lib/python3.11/site-packages/torch/nn/modules/module.py:1511, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1509     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1510 else:
# -> 1511     return self._call_impl(*args, **kwargs)
#
# File /opt/homebrew/lib/python3.11/site-packages/torch/nn/modules/module.py:1520, in Module._call_impl(self, *args, **kwargs)
#    1515 # If we don't have any hooks, we want to skip the rest of the logic in
#    1516 # this function, and just call forward.
#    1517 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1518         or _global_backward_pre_hooks or _global_backward_hooks
#    1519         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1520     return forward_call(*args, **kwargs)
#    1522 try:
#    1523     result = None
#
# File /opt/homebrew/lib/python3.11/site-packages/torch/nn/modules/pooling.py:164, in MaxPool2d.forward(self, input)
#     163 def forward(self, input: Tensor):
# --> 164     return F.max_pool2d(input, self.kernel_size, self.stride,
#     165                         self.padding, self.dilation, ceil_mode=self.ceil_mode,
#     166                         return_indices=self.return_indices)
#
# File /opt/homebrew/lib/python3.11/site-packages/torch/_jit_internal.py:499, in boolean_dispatch.<locals>.fn(*args, **kwargs)
#     497     return if_true(*args, **kwargs)
#     498 else:
# --> 499     return if_false(*args, **kwargs)
#
# File /opt/homebrew/lib/python3.11/site-packages/torch/nn/functional.py:796, in _max_pool2d(input, kernel_size, stride, padding, dilation, ceil_mode, return_indices)
#     794 if stride is None:
#     795     stride = torch.jit.annotate(List[int], [])
# --> 796 return torch.max_pool2d(input, kernel_size, stride, padding, dilation, ceil_mode)
#
# KeyboardInterrupt:
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
